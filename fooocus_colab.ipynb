# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git

# %cd /content/Fooocus/models/upscale models/
# !uget -0 fooocus_upscaler_s409985eS.bin https://huggingface.co/lllyasviel/misc/resolvz/main/fooocus_upscaler_s409985e5.bin7dowload=true

# %cd /content/Fooocus
# !python entry_with_update.py -share
